# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df_read = pd.read_csv("BDM-Cluster-Centers.csv")

df = pd.DataFrame(df_read, columns=["Cluster",'Gardening & Lawn Care', 'Price','Rating'])
print (df)
# Out:
#    Cluster  Gardening & Lawn Care  Price  Rating
# 0        0               0.361991     66       4
# 1        1               0.509283     55       1
# 2        2               0.377104     60       5
# 3        3               0.467432     59       2
# 4        4               0.423471     63       3

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = np.array(df['Gardening & Lawn Care'])
y = np.array(df['Price'])
z = np.array(df['Rating'])

ax.scatter(x,y,z, marker="s", c=df["Cluster"], s=40, cmap="RdBu")

plt.show()
